-- %% [markdown]
-- # 02_refresh_materialized_views
--
-- Notebook SQL para el modelo dimensional FinPay.

-- %%
REFRESH MATERIALIZED VIEW fintech_finpay_dev.gold.fact_transactions;

-- %%
REFRESH MATERIALIZED VIEW fintech_finpay_dev.gold.dim_merchant;

-- %%
REFRESH MATERIALIZED VIEW fintech_finpay_dev.gold.dim_user;

-- %%
REFRESH MATERIALIZED VIEW fintech_finpay_dev.gold.dim_channel;

-- %%
REFRESH MATERIALIZED VIEW fintech_finpay_dev.gold.dim_date;
